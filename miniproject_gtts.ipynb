# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkGeunHae/miniproject/blob/main/miniproject_gtts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 미니 프로젝트
# - 영어단어장 프로그램 만들기

# %%
# !pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gTTS) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2024.2.2)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.5.1

# %%
from gtts import gTTS
from IPython.display import Audio
import time

def speaker(stmt):
    kor_wav = gTTS(stmt, lang = 'ko')
    kor_wav.save('kor.wav')
    display(Audio('kor.wav', autoplay=True))


#1. 단어등록
def w_add(dictionary):
    key=input('새 단어 : ')
    print(f'{key}',end='')
    speaker(f'새로 등록하신 단어는 {key}입니다.')
    value=input('의 뜻 : ')
    speaker(f'새로 등록하신 단어의 뜻은 {value}입니다.')
    dictionary[key]=value

#2. 단어검색
def w_search(dictionary):

    key=input('검색할 단어 : ')
    print(dictionary[key])
    speaker(f'검색하신 단어는 {key}이고 뜻은 {dictionary[key]}입니다.')

#3. 단어삭제
def w_delete(dictionary):
    key = input('삭제할 단어 : ')
    if key in dictionary:  # 딕셔너리에 입력된 키 값이 존재하는지 확인
        del dictionary[key]  # 키 값이 존재하면 해당 단어를 삭제
        print(f'"{key}" 단어 삭제됨!')
        speaker(f'삭제하신 단어는 {key}입니다.')
    else:
        print(f'"{key}" 단어는 미등록 단어')
        speaker(f'{key}는 미등록 단어입니다.')

#4. 모든단어보기
def w_show(dictionary):
    print(dictionary)
    time.sleep(3)
    speaker(f'등록되어 있는 모든 단어는 {dictionary}입니다.')


dictionary=dict()    # 빈 딕셔너리 생성

#0. 종료하기
def quit():
    print('프로그램을 종료합니다.')

while True:


    menu='''---선택메뉴--
    1. 단어 등록
    2. 단어 검색
    3. 단어 삭제
    4. 모든 단어 보기
    0. 종료하기
    --------------------'''
    print(menu,end='')

    time.sleep(5)

    speaker(menu)

    time.sleep(2)

    select=input('선택:')

    if select=='1':
        speaker('새 단어를 등록하세요')
        w_add(dictionary)

    elif select=='2':
       speaker('단어를 검색하세요')
       w_search(dictionary)

    elif select=='3':
       speaker('삭제할 단어를 입력하세요')
       w_delete(dictionary)

    elif select=='4':
       speaker('모든 단어를 보여주세요')
       w_show(dictionary)

    elif  select=='0':
        speaker('종료합니다.')
        quit()
        break
# Out:
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:1
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 새 단어 : apple
# apple
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 의 뜻 : 사과
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:1
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 새 단어 : orange
# orange
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 의 뜻 : 오렌지
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:3
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 삭제할 단어 : apple
# "apple" 단어 삭제됨!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:4
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# {'orange': '오렌지'}
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:4
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# {'orange': '오렌지'}
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:3
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 삭제할 단어 : grape
# "grape" 단어는 미등록 단어
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b26644673bb5> in <cell line: 51>()
#      67     time.sleep(2)
#      68
# ---> 69     select=input('선택:')
#      70
#      71     if select=='1':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (2.5.2)

# %%
# !pip install playsound
# Out:
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py) ... done
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7020 sha256=00fa4f9f6c5b3418b0cb6ba8e2883d7035f071db79387347e7ee85f8cfed6ecd
#   Stored in directory: /root/.cache/pip/wheels/90/89/ed/2d643f4226fc8c7c9156fc28abd8051e2d2c0de37ae51ac45c
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0

# %%
from gtts import gTTS
import pygame


pygame.mixer.init(devicename='pulse')


# pygame 초기화
pygame.mixer.init()


def speaker(stmt):
    kor_wav = gTTS(stmt, lang='ko')
    kor_wav.save('kor.wav')
    pygame.mixer.music.load("kor.wav")
    pygame.mixer.music.play()
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)

#1. 단어등록
def w_add(dictionary):
    key=input('새 단어 : ')
    print(f'{key}',end='')
    value=input('의 뜻 : ')
    dictionary[key]=value

#2. 단어검색
def w_search(dictionary):
    key=input('검색할 단어 : ')
    print(dictionary.get(key, '미등록 단어'))

#3. 단어삭제
def w_delete(dictionary):
    key = input('삭제할 단어 : ')
    if key in dictionary:
        del dictionary[key]
        print(f'"{key}" 단어 삭제됨!')
    else:
        print(f'"{key}" 단어는 미등록 단어')

#4. 모든단어보기
def w_show(dictionary):
    print(dictionary)

dictionary = {}  # 빈 딕셔너리 생성

#0. 종료하기
def quit():
    print('프로그램을 종료합니다.')

# 메인 루프
while True:
    menu = '''---선택메뉴--
    1. 단어 등록
    2. 단어 검색
    3. 단어 삭제
    4. 모든 단어 보기
    0. 종료하기
    --------------------'''
    print(menu)
    speaker(menu)
    select = input('선택:')

    if select == '1':
        speaker('새 단어를 등록하세요')
        w_add(dictionary)

    elif select == '2':
        speaker('단어를 검색하세요')
        w_search(dictionary)

    elif select == '3':
        speaker('단어를 삭제하세요')
        w_delete(dictionary)

    elif select == '4':
        speaker('모든 단어를 보여주세요')
        w_show(dictionary)

    elif select == '0':
        speaker('종료합니다.')
        quit()
        break
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-15-e40e11d62952> in <cell line: 5>()
#       3
#       4
# ----> 5 pygame.mixer.init(devicename='pulse')
#       6
#       7
#
# error: No such device.
