# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkGeunHae/miniproject/blob/main/miniproject_gtts_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 미니 프로젝트
# - 영어단어장 프로그램 만들기

# %%
# !pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gTTS) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2024.2.2)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.5.1

# %%
from gtts import gTTS
from IPython.display import Audio
import time

def speaker(stmt):
    kor_wav = gTTS(stmt, lang = 'ko')
    kor_wav.save('kor.wav')
    display(Audio('kor.wav', autoplay=True))


#1. 단어등록
def w_add(dictionary):
    key=input('새 단어 : ')
    print(f'{key}',end='')
    value=input('의 뜻 : ')
    print(f'등록단어:{key},뜻:{value}')
    speaker(f'새로 등록하신 단어는 {key}이고, 뜻은 {value}입니다.')
    dictionary[key]=value



#2. 단어검색
def w_search(dictionary):
    search_term = input('검색할 단어 또는 뜻 : ')
    found = False

    # key 검색
    if search_term in dictionary:
        meaning = dictionary[search_term]
        print(f'단어: {search_term}, 뜻: {meaning}')
        speaker(f'검색하신 단어는 {search_term}이고 뜻은 {meaning}입니다.')
        found = True

    # value 검색
    for key, value in dictionary.items():
        if value == search_term:
            print(f'뜻: {value},단어: {key}')
            speaker(f'검색하신 뜻은 {value}이고 단어는 {key}입니다.')
            found = True

    # 일부 검색
    for key, value in dictionary.items():
        if search_term in key or search_term in value:
            print(f'단어: {key}, 뜻: {value}')
            found = True

    # 검색 결과가 없는 경우
    if not found:
        print(f'"{search_term}"에 대한 검색 결과가 없습니다.')
        speaker(f'"{search_term}"에 대한 검색 결과가 없습니다.')



#3. 단어삭제
def w_delete(dictionary):
    key = input('삭제할 단어 : ')
    if key in dictionary:  # 딕셔너리에 입력된 키 값이 존재하는지 확인
        del dictionary[key]  # 키 값이 존재하면 해당 단어를 삭제
        print(f'"{key}" 단어 삭제됨!')
        speaker(f'삭제하신 단어는 {key}입니다.')
    else:
        print(f'"{key}" 단어는 미등록 단어')
        speaker(f'{key}는 미등록 단어입니다.')


#4. 모든단어보기
def w_show(dictionary):
    print(dictionary)
    time.sleep(3)
    speaker(f'등록되어 있는 모든 단어는 {dictionary}입니다.')


dictionary=dict()    # 빈 딕셔너리 생성

#0. 종료하기
def quit():
    print('프로그램을 종료합니다.')

while True:


    menu='''---선택메뉴--
    1. 단어 등록
    2. 단어 검색
    3. 단어 삭제
    4. 모든 단어 보기
    0. 종료하기
    --------------------
    원하시는 메뉴를 선택해주세요'''
    print(menu,end='')

    time.sleep(5)

    speaker(menu)

    time.sleep(2)

    select=input('선택:')

    if select=='1':
        speaker('새 단어를 등록하세요')
        w_add(dictionary)

    elif select=='2':
       speaker('단어를 검색하세요')
       w_search(dictionary)

    elif select=='3':
       speaker('삭제할 단어를 입력하세요')
       w_delete(dictionary)

    elif select=='4':
       speaker('모든 단어를 보여주세요')
       w_show(dictionary)

    elif  select=='0':
        speaker('종료합니다.')
        quit()
        break
# Out:
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:1
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 새 단어 : apple
# apple의 뜻 : 사과
# 등록단어:apple,뜻:사과
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:2
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 검색할 단어 또는 뜻 : 사
# 단어: apple, 뜻: 사과
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:4
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# {'apple': '사과'}
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:0
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 프로그램을 종료합니다.
