# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkGeunHae/miniproject/blob/main/miniproject_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %% [markdown]
# # 파일에 추가하는 거 포함

# %%
from gtts import gTTS
from IPython.display import Audio, display
import time

def speaker(stmt):
    kor_wav = gTTS(stmt, lang='ko')
    kor_wav.save('kor.wav')
    display(Audio('kor.wav', autoplay=True))

# 파일에 내용을 추가하는 함수
def write_to_file(stmt):
    with open('output.txt', 'a') as file:  # 'a' 모드는 파일에 내용을 추가합니다.
        file.write(stmt + '\n')

#1. 단어등록
def w_add(dictionary):
    while True:
        key = input('새 단어 : ')
        if key in dictionary:
            msg = f'입력하신 {key}는 이미 등록되어 있는 단어입니다.'
            print(msg)
            speaker(msg)
            write_to_file(msg)
        else:
            break
    value = input('의 뜻 : ')
    msg = f'등록단어: {key}, 뜻: {value}'
    print(msg)
    speaker(f'새로 등록하신 단어는 {key}이고, 뜻은 {value}입니다.')
    write_to_file(msg)  # 등록된 단어를 파일에 저장
    dictionary[key] = value

#2. 단어검색
def w_search(dictionary):
    search_term = input('검색할 단어 또는 뜻 : ')
    found = False

    # key 검색
    if search_term in dictionary:
        meaning = dictionary[search_term]
        msg = f'검색하신 단어는 {search_term}이고 뜻은 {meaning}입니다.'
        print(msg)
        speaker(msg)
        write_to_file(msg)  # 검색된 단어를 파일에 저장
        found = True

    # value 검색
    value_searched = False  # value 검색 여부를 나타내는 변수 추가
    for key, value in dictionary.items():
        if value == search_term:
            msg = f'검색하신 뜻은 {value}이고 단어는 {key}입니다.'
            print(msg)
            speaker(msg)
            write_to_file(msg)  # 검색된 단어를 파일에 저장
            found = True
            value_searched = True  # value 검색이 실행된 경우 변수를 True로 설정

    # key 검색이나 value 검색이 모두 실행되지 않았고 value 검색이 실행된 적도 없는 경우에만 일부 검색 수행
    if not found and not value_searched:
        for key, value in dictionary.items():
            if search_term in key or search_term in value:
                msg = f'검색하신 일부를 포함하는 단어는 {key}이고 뜻은 {value}입니다.'
                print(msg)
                speaker(msg)
                write_to_file(msg)  # 검색된 단어를 파일에 저장
                time.sleep(5)
                found = True

    # 검색 결과가 없는 경우
    if not found:
        msg = f'"{search_term}"에 대한 검색 결과가 없습니다.'
        print(msg)
        speaker(msg)
        write_to_file(msg)  # 검색결과가 없는 단어를 파일에 저장

#3. 단어삭제
def w_delete(dictionary):
    key = input('삭제할 단어 : ')
    if key in dictionary:  # 딕셔너리에 입력된 키 값이 존재하는지 확인
        del dictionary[key]  # 키 값이 존재하면 해당 단어를 삭제
        msg = f'"{key}" 단어 삭제됨!'
        print(msg)
        speaker(f'삭제하신 단어는 {key}입니다.')
    else:
        msg = f'"{key}" 단어는 미등록 단어'
        print(msg)
        speaker(f'{key}는 미등록 단어입니다.')
    write_to_file(msg)

#4. 모든단어보기
def w_show(dictionary):
    msg = str(dictionary)
    print(msg)
    time.sleep(3)
    speaker(f'등록되어 있는 모든 단어는 {msg}입니다.')
    write_to_file(msg)

#0. 종료하기
def quit():
    msg = '프로그램을 종료합니다.'
    print(msg)
    speaker(msg)
    write_to_file(msg)

dictionary = dict()    # 빈 딕셔너리 생성

# 메뉴 출력 여부를 나타내는 변수
menu_displayed = False

while True:
    menu = '''---선택메뉴--
    1. 단어 등록
    2. 단어 검색
    3. 단어 삭제
    4. 모든 단어 보기
    0. 종료하기
    --------------------
    원하시는 메뉴를 선택해주세요'''
    print(menu, end='')

    time.sleep(5)

    if not menu_displayed:
        speaker(menu)
        menu_displayed = True

    time.sleep(2)

    select = input('선택:')

    if select == '1':
        speaker('새 단어를 등록하세요')
        w_add(dictionary)

    elif select == '2':
        speaker('단어를 검색하세요')
        w_search(dictionary)

    elif select == '3':
        speaker('삭제할 단어를 입력하세요')
        w_delete(dictionary)

    elif select == '4':
        speaker('모든 단어를 보여주세요')
        w_show(dictionary)

    elif select == '0':
        quit()
        break
# Out:
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 선택:1
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 새 단어 : apple
# 의 뜻 : 사과
# 등록단어: apple, 뜻: 사과
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:1
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 새 단어 : grape
# 의 뜻 : 포도
# 등록단어: grape, 뜻: 포도
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:1
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 새 단어 : melon
# 의 뜻 : 수박
# 등록단어: melon, 뜻: 수박
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:1
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 새 단어 : peach
# 의 뜻 : 복숭아
# 등록단어: peach, 뜻: 복숭아
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:4
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# {'apple': '사과', 'grape': '포도', 'melon': '수박', 'peach': '복숭아'}
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:2
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 검색할 단어 또는 뜻 : e
# 검색하신 일부를 포함하는 단어는 apple이고 뜻은 사과입니다.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 검색하신 일부를 포함하는 단어는 grape이고 뜻은 포도입니다.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 검색하신 일부를 포함하는 단어는 melon이고 뜻은 수박입니다.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 검색하신 일부를 포함하는 단어는 peach이고 뜻은 복숭아입니다.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:2
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 검색할 단어 또는 뜻 : 복숭아
# 검색하신 뜻은 복숭아이고 단어는 peach입니다.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:melon
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:2
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 검색할 단어 또는 뜻 : melon
# 검색하신 단어는 melon이고 뜻은 수박입니다.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:1
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 새 단어 : pear
# 의 뜻 : 배
# 등록단어: pear, 뜻: 배
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:4
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# {'apple': '사과', 'grape': '포도', 'melon': '수박', 'peach': '복숭아', 'pear': '배'}
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:3
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 삭제할 단어 : pear
# "pear" 단어 삭제됨!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:4
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# {'apple': '사과', 'grape': '포도', 'melon': '수박', 'peach': '복숭아'}
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---선택메뉴--
#     1. 단어 등록
#     2. 단어 검색
#     3. 단어 삭제
#     4. 모든 단어 보기
#     0. 종료하기
#     --------------------
#     원하시는 메뉴를 선택해주세요선택:0
# 프로그램을 종료합니다.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
